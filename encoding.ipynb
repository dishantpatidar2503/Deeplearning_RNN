# %%
import numpy as np 

docs = [
    'machine learning basics',
    'deep learning model',
    'artificial intelligence future',
    'python for data science',
    'data analysis using pandas',
    'neural network training',
    'tensorflow and keras',
    'cnn for image classification',
    'rnn for sequence data',
    'natural language processing',
    'supervised learning algorithm',
    'unsupervised clustering method',
    'decision tree classifier',
    'random forest model',
    'support vector machine',
    'gradient descent optimization',
    'computer vision project',
    'image recognition system',
    'sentiment analysis using nlp',
    'chatbot using deep learning'
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(oov_token='<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'learning': 2,
#  'for': 3,
#  'data': 4,
#  'using': 5,
#  'machine': 6,
#  'deep': 7,
#  'model': 8,
#  'analysis': 9,
#  'image': 10,
#  'basics': 11,
#  'artificial': 12,
#  'intelligence': 13,
#  'future': 14,
#  'python': 15,
#  'science': 16,
#  'pandas': 17,
#  'neural': 18,
#  'network': 19,
#  'training': 20,
#  'tensorflow': 21,
#  'and': 22,
#  'keras': 23,
#  'cnn': 24,
#  'classification': 25,
#  'rnn': 26,
#  'sequence': 27,
#  'natural': 28,
#  'language': 29,
#  'processing': 30,
#  'supervised': 31,
#  'algorithm': 32,
#  'unsupervised': 33,
#  'clustering': 34,
#  'method': 35,
#  'decision': 36,
#  'tree': 37,
#  'classifier': 38,
#  'random': 39,
#  'forest': 40,
#  'support': 41,
#  'vector': 42,
#  'gradient': 43,
#  'descent': 44,
#  'optimization': 45,
#  'computer': 46,
#  'vision': 47,
#  'project': 48,
#  'recognition': 49,
#  'system': 50,
#  'sentiment': 51,
#  'nlp': 52,
#  'chatbot': 53}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('machine', 2),
#              ('learning', 4),
#              ('basics', 1),
#              ('deep', 2),
#              ('model', 2),
#              ('artificial', 1),
#              ('intelligence', 1),
#              ('future', 1),
#              ('python', 1),
#              ('for', 3),
#              ('data', 3),
#              ('science', 1),
#              ('analysis', 2),
#              ('using', 3),
#              ('pandas', 1),
#              ('neural', 1),
#              ('network', 1),
#              ('training', 1),
#              ('tensorflow', 1),
#              ('and', 1),
#              ('keras', 1),
#              ('cnn', 1),
#              ('image', 2),
#              ('classification', 1),
#              ('rnn', 1),
#              ('sequence', 1),
#              ('natural', 1),
#              ('language', 1),
#              ('processing', 1),
#              ('supervised', 1),
#              ('algorithm', 1),
#              ('unsupervised', 1),
#              ('clustering', 1),
#              ('method', 1),
#              ('decision', 1),
#              ('tree', 1),
#              ('classifier', 1),
#              ('random', 1),
#              ('forest', 1),
#              ('support', 1),
#              ('vector', 1),
#              ('gradient', 1),
#              ('descent', 1),
#              ('optimization', 1),
#              ('computer', 1),
#              ('vision', 1),
#              ('project', 1),
#              ('recognition', 1),
#              ('system', 1),
#              ('sentiment', 1),
#              ('nlp', 1),
#              ('chatbot', 1)])

# %%
tokenizer.document_count
# Out:
# 20

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[6, 2, 11],
#  [7, 2, 8],
#  [12, 13, 14],
#  [15, 3, 4, 16],
#  [4, 9, 5, 17],
#  [18, 19, 20],
#  [21, 22, 23],
#  [24, 3, 10, 25],
#  [26, 3, 27, 4],
#  [28, 29, 30],
#  [31, 2, 32],
#  [33, 34, 35],
#  [36, 37, 38],
#  [39, 40, 8],
#  [41, 42, 6],
#  [43, 44, 45],
#  [46, 47, 48],
#  [10, 49, 50],
#  [51, 9, 5, 52],
#  [53, 5, 7, 2]]

# %%
# !pip install pad_sequences
# Out:
# Requirement already satisfied: pad_sequences in c:\users\hp\anaconda3\lib\site-packages (0.6.1)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\anaconda3\Lib\site-packages)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sequences = pad_sequences(sequences,padding = 'post')

# %%
sequences
# Out:
# array([[ 6,  2, 11,  0],
#        [ 7,  2,  8,  0],
#        [12, 13, 14,  0],
#        [15,  3,  4, 16],
#        [ 4,  9,  5, 17],
#        [18, 19, 20,  0],
#        [21, 22, 23,  0],
#        [24,  3, 10, 25],
#        [26,  3, 27,  4],
#        [28, 29, 30,  0],
#        [31,  2, 32,  0],
#        [33, 34, 35,  0],
#        [36, 37, 38,  0],
#        [39, 40,  8,  0],
#        [41, 42,  6,  0],
#        [43, 44, 45,  0],
#        [46, 47, 48,  0],
#        [10, 49, 50,  0],
#        [51,  9,  5, 52],
#        [53,  5,  7,  2]], dtype=int32)

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train.shape
# Out:
# (25000,)

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  31050,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
len(X_train[0])
# Out:
# 218

# %%
len(X_train[1])
# Out:
# 189

# %%
len(X_train[2])
# Out:
# 141

# %%
len(X_test[0])
# Out:
# 68

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train[0]
# Out:
# array([2071,   56,   26,  141,    6,  194, 7486,   18,    4,  226,   22,
#          21,  134,  476,   26,  480,    5,  144,   30, 5535,   18,   51,
#          36,   28,  224,   92,   25,  104,    4,  226,   65,   16,   38,
#        1334,   88,   12,   16,  283,    5,   16, 4472,  113,  103,   32,
#          15,   16, 5345,   19,  178,   32], dtype=int32)

# %%
model = Sequential()

model.add(SimpleRNN(32,input_shape=(50,1),return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5096 - loss: 0.6946 - val_accuracy: 0.5037 - val_loss: 0.6935
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5059 - loss: 0.6932 - val_accuracy: 0.5053 - val_loss: 0.6938
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5106 - loss: 0.6925 - val_accuracy: 0.5030 - val_loss: 0.6941
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5057 - loss: 0.6925 - val_accuracy: 0.5048 - val_loss: 0.6945
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5103 - loss: 0.6925 - val_accuracy: 0.5063 - val_loss: 0.6943

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5063 - loss: 0.6943
# Accuracy: 0.5063199996948242

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/hp/Deep_learning/.git/
